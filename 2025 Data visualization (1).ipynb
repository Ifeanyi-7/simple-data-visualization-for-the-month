# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Creating a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', np.nan, 'Hannah'],
    'Age': [25, 30, np.nan, 40, 35, 50, 29, 33],
    'Salary': [50000, 60000, 55000, np.nan, 75000, 80000, 72000, 70000],
    'Department': ['HR', 'Finance', 'IT', 'IT', 'Finance', 'HR', 'HR', np.nan]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob  30.0  60000.0    Finance
# 2  Charlie   NaN  55000.0         IT
# 3    David  40.0      NaN         IT
# 4      Eve  35.0  75000.0    Finance
# 5    Frank  50.0  80000.0         HR
# 6      NaN  29.0  72000.0         HR
# 7   Hannah  33.0  70000.0        NaN

# %%
# 2. Data Cleaning
# Handling missing values

# %%
df.fillna({'Age': df['Age'].median(), 'Salary': df['Salary'].mean(), 'Department': 'Unknown'}, inplace=True)

# %%
df.dropna(subset=['Name'], inplace=True)

# %%
# Removing duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
# Converting data types if necessary

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.reset_index(drop=True, inplace=True)

# %%
print(df)
# Out:
#       Name  Age   Salary Department
# 0    Alice   25  50000.0         HR
# 1      Bob   30  60000.0    Finance
# 2  Charlie   33  55000.0         IT
# 3    David   40  66000.0         IT
# 4      Eve   35  75000.0    Finance
# 5    Frank   50  80000.0         HR
# 6   Hannah   33  70000.0    Unknown

# %%
# 3. Basic Statistics

# %%
print(df.describe())
# Out:
#              Age        Salary
# count   7.000000      7.000000
# mean   35.142857  65142.857143
# std     7.988086  10807.845475
# min    25.000000  50000.000000
# 25%    31.500000  57500.000000
# 50%    33.000000  66000.000000
# 75%    37.500000  72500.000000
# max    50.000000  80000.000000

# %%
# 4. Data Visualization

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], bins=5, kde=True, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Department', y='Salary', data=df, estimator=np.mean, ci=None, palette='coolwarm')
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()
# Out:
# C:\Users\GM\AppData\Local\Temp\ipykernel_14944\3255013991.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Department', y='Salary', data=df, estimator=np.mean, ci=None, palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Salary'], color='green')
plt.title('Salary Distribution')
plt.show()

# %%
# Ifeanyi Isaiah Nsude worl!
##THANK YOU
